# %% [markdown]
# # Домашнее задание 6

# %% [markdown]
# ### Задание 1

# %%
from datetime import datetime

def the_moscow_time_date(date):
    dt = datetime.strptime(date, '%A, %B %d, %Y')
# Работает в Windows в Jupiter Notebook
# В отличной среде функционирования скрипта возможны проблемы ввиду формата даты без "0"
# Так как на момент выполнения задания регулярные выражения для редактирования str еще не проходил - оставляю так
    
    return dt

# %%
the_moscow_time_date('Wednesday, October 02, 2002')
# Out:
# datetime.datetime(2002, 10, 2, 0, 0)

# %%
def the_guardian_date(date):
    dt = datetime.strptime(date, '%A, %d.%m.%y')
# Из условия задачи не понятно, что в формате первое - дата или месяц
# The Guardian газета из Великобритании, считаю что формат дд.мм.гг 
    
    return dt

# %%
the_guardian_date('Friday, 11.10.13')
# Out:
# datetime.datetime(2013, 10, 11, 0, 0)

# %%
def daily_news(date):
    dt = datetime.strptime(date, '%A, %d %B %Y')
    
    return dt

# %%
daily_news('Thursday, 18 August 1977')
# Out:
# datetime.datetime(1977, 8, 18, 0, 0)

# %% [markdown]
# ### Задание 2

# %%
from datetime import datetime
from datetime import timedelta

def date_range(start_date, end_date):

    try:
        str_start_date = datetime.strptime(start_date, '%Y-%m-%d')
        str_end_date = datetime.strptime(end_date, '%Y-%m-%d')
        temp_date = str_start_date
        str_dates = []
        while str_end_date >= temp_date:
            element_str_dates = temp_date.strftime('%Y-%m-%d')
            str_dates.append(temp_date.strftime('%Y-%m-%d')) 
            temp_date += timedelta(days=1)
        
        return print(str_dates)
    
    except:
        str_dates = []
        return str_dates

# %%
date_range('2022-02-24', '2022-09-21')
# Out:
# ['2022-02-24', '2022-02-25', '2022-02-26', '2022-02-27', '2022-02-28', '2022-03-01', '2022-03-02', '2022-03-03', '2022-03-04', '2022-03-05', '2022-03-06', '2022-03-07', '2022-03-08', '2022-03-09', '2022-03-10', '2022-03-11', '2022-03-12', '2022-03-13', '2022-03-14', '2022-03-15', '2022-03-16', '2022-03-17', '2022-03-18', '2022-03-19', '2022-03-20', '2022-03-21', '2022-03-22', '2022-03-23', '2022-03-24', '2022-03-25', '2022-03-26', '2022-03-27', '2022-03-28', '2022-03-29', '2022-03-30', '2022-03-31', '2022-04-01', '2022-04-02', '2022-04-03', '2022-04-04', '2022-04-05', '2022-04-06', '2022-04-07', '2022-04-08', '2022-04-09', '2022-04-10', '2022-04-11', '2022-04-12', '2022-04-13', '2022-04-14', '2022-04-15', '2022-04-16', '2022-04-17', '2022-04-18', '2022-04-19', '2022-04-20', '2022-04-21', '2022-04-22', '2022-04-23', '2022-04-24', '2022-04-25', '2022-04-26', '2022-04-27', '2022-04-28', '2022-04-29', '2022-04-30', '2022-05-01', '2022-05-02', '2022-05-03', '2022-05-04', '2022-05-05', '20
# ...
